# %%
import warnings

# Ignore specific warning temporarily
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="Number of labels is 1.*")

# %% [markdown]
# # Import data

# %%
import pandas as pd

data = pd.read_csv('data/Anime Recommendation/anime.csv')

# We only need one identifier for the animes, in this case we will use the name
data.drop(columns = ['MAL_ID', 'English name', 'Japanese name'], inplace = True)
data.head()
# Out:
#                               Name Score  \
# 0                     Cowboy Bebop  8.78
# 1  Cowboy Bebop: Tengoku no Tobira  8.39
# 2                           Trigun  8.24
# 3               Witch Hunter Robin  7.27
# 4                   Bouken Ou Beet  6.98
#
#                                               Genres   Type Episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#                           Aired    Premiered  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1                   Sep 1, 2001      Unknown
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004
#
#                                            Producers  \
# 0                                      Bandai Visual
# 1                             Sunrise, Bandai Visual
# 2                               Victor Entertainment
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...
# 4                                   TV Tokyo, Dentsu
#
#                               Licensors         Studios  ...  Score-10  \
# 0      Funimation, Bandai Entertainment         Sunrise  ...  229170.0
# 1           Sony Pictures Entertainment           Bones  ...   30043.0
# 2  Funimation, Geneon Entertainment USA        Madhouse  ...   50229.0
# 3      Funimation, Bandai Entertainment         Sunrise  ...    2182.0
# 4                               Unknown  Toei Animation  ...     312.0
#
#     Score-9   Score-8  Score-7  Score-6  Score-5  Score-4  Score-3  Score-2  \
# 0  182126.0  131625.0  62330.0  20688.0   8904.0   3184.0   1357.0    741.0
# 1   49201.0   49505.0  22632.0   5805.0   1877.0    577.0    221.0    109.0
# 2   75651.0   86142.0  49432.0  15376.0   5838.0   1965.0    664.0    316.0
# 3    4806.0   10128.0  11618.0   5709.0   2920.0   1083.0    353.0    164.0
# 4     529.0    1242.0   1713.0   1068.0    634.0    265.0     83.0     50.0
#
#    Score-1
# 0   1580.0
# 1    379.0
# 2    533.0
# 3    131.0
# 4     27.0
#
# [5 rows x 32 columns]

# %% [markdown]
# # Explore the dataset
# * Do we have null data?
# * Are there duplicated values?
# * What type of data is each column?
# * The categorical data has levels (easy - difficult or less - more)?

# %% [markdown]
# ## 1. Do we have null data?

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# This can also exist as a string such as 'Unknown' or 'Undefined', in data frame we can see there are some 'Unknown', lets find which features have this as categorical data, and how much it represents in percentage of the whole dataset.

# %%
categorical_data = data.columns[data.dtypes == object]
unknown_cat = []
percentages = []
for cat in categorical_data:
    if 'Unknown' in data[cat].unique():
        unknown_cat.append(cat)
        percentages.append(len(data[data[cat] == 'Unknown'])*100/len(data))
        print(f"Unkwnowns in {cat}: {len(data[data[cat] == 'Unknown'])*100/len(data)}%")
# Out:
# Unkwnowns in Score: 29.273431272064684%
# Unkwnowns in Genres: 0.358729074137342%
# Unkwnowns in Type: 0.21068215465208973%
# Unkwnowns in Episodes: 2.9381619405534676%
# Unkwnowns in Aired: 1.759480696959344%
# Unkwnowns in Premiered: 72.98143719394146%
# Unkwnowns in Producers: 44.379911171848306%
# Unkwnowns in Licensors: 77.53103291196902%
# Unkwnowns in Studios: 40.30862088600387%
# Unkwnowns in Source: 20.31089853091903%
# Unkwnowns in Duration: 3.160232319781346%
# Unkwnowns in Rating: 3.9175492540712904%
# Unkwnowns in Ranked: 10.033025851269787%
# Unkwnowns in Score-10: 2.4883270698098165%
# Unkwnowns in Score-9: 18.033253615761303%
# Unkwnowns in Score-8: 7.806627946703109%
# Unkwnowns in Score-7: 2.8641384808108414%
# Unkwnowns in Score-6: 2.9096913791139962%
# Unkwnowns in Score-5: 3.3253615761302813%
# Unkwnowns in Score-4: 5.563147705272748%
# Unkwnowns in Score-3: 7.442204760277873%
# Unkwnowns in Score-2: 9.093497323767224%
# Unkwnowns in Score-1: 2.6135975401434917%

# %%
import matplotlib.pyplot as plt
# Combine the categories and values, then sort them by value in decreasing order
sorted_data = sorted(zip(unknown_cat, percentages), key=lambda x: x[1], reverse=True)
sorted_categories, sorted_values = zip(*sorted_data)

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(sorted_categories, sorted_values, color='skyblue')
plt.xlabel('Category')
plt.ylabel('Unknown data (%)')
plt.title('Unknown values per feature')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest value on top
plt.show()

# %% [markdown]
# ## 2. Are there duplicated values?

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3. What type of data is each column?

# %%
data.dtypes
# Out:
# Name             object
# Score            object
# Genres           object
# Type             object
# Episodes         object
# Aired            object
# Premiered        object
# Producers        object
# Licensors        object
# Studios          object
# Source           object
# Duration         object
# Rating           object
# Ranked           object
# Popularity        int64
# Members           int64
# Favorites         int64
# Watching          int64
# Completed         int64
# On-Hold           int64
# Dropped           int64
# Plan to Watch     int64
# Score-10         object
# Score-9          object
# Score-8          object
# Score-7          object
# Score-6          object
# Score-5          object
# Score-4          object
# Score-3          object
# Score-2          object
# Score-1          object
# dtype: object

# %% [markdown]
# We can see that numerical data (for example the scores) are objects instead of floats

# %% [markdown]
# ## The categorical data has levels?

# %%
categorical_data = data.columns[data.dtypes == object]
for cat in categorical_data:
    # Only intented categorical data
    try:
        float(data[cat][0])
    except:
        print(f"{cat}: {data[cat].unique()}")
        print("")
# Out:
# Name: ['Cowboy Bebop' 'Cowboy Bebop: Tengoku no Tobira' 'Trigun' ...
#  'Higurashi no Naku Koro ni Sotsu' 'Yama no Susume: Next Summit'
#  'Scarlet Nexus']
#
# Genres: ['Action, Adventure, Comedy, Drama, Sci-Fi, Space'
#  'Action, Drama, Mystery, Sci-Fi, Space'
#  'Action, Sci-Fi, Adventure, Comedy, Drama, Shounen' ...
#  'Horror, Demons, Supernatural, Thriller' 'Sci-Fi, Space, Vampire'
#  'Adventure, Mystery, Supernatural']
#
# Type: ['TV' 'Movie' 'OVA' 'Special' 'ONA' 'Music' 'Unknown']
#
# Aired: ['Apr 3, 1998 to Apr 24, 1999' 'Sep 1, 2001' 'Apr 1, 1998 to Sep 30, 1998'
#  ... 'Sep 10, 2021 to ?' 'Mar 14, 2021' 'Mar 17, 2021 to ?']
#
# Premiered: ['Spring 1998' 'Unknown' 'Summer 2002' 'Fall 2004' 'Spring 2005'
#  'Fall 2002' 'Spring 2004' 'Fall 1999' 'Fall 2001' 'Spring 2003'
#  'Fall 1995' 'Fall 1997' 'Winter 1996' 'Spring 2002' 'Winter 2005'
#  'Spring 2001' 'Spring 1999' 'Fall 2003' 'Summer 2003' 'Summer 2004'
#  'Fall 2005' 'Winter 2002' 'Summer 2005' 'Spring 1979' 'Spring 1985'
#  'Spring 1986' 'Spring 1993' 'Spring 1995' 'Spring 1996' 'Spring 1994'
#  'Winter 1994' 'Spring 2000' 'Fall 1996' 'Spring 1997' 'Winter 2004'
#  'Winter 1998' 'Summer 2001' 'Winter 1999' 'Fall 1998' 'Fall 1993'
#  'Summer 2000' 'Fall 2000' 'Winter 2003' 'Spring 1989' 'Winter 1986'
#  'Summer 1997' 'Summer 1999' 'Winter 1979' 'Winter 2001' 'Spring 1978'
#  'Winter 1973' 'Spring 1991' 'Fall 1973' 'Fall 1989' 'Fall 1994'
#  'Winter 1992' 'Fall 1979' 'Summer 1998' 'Winter 2000' 'Winter 2006'
#  'Summer 1995' 'Fall 1992' 'Summer 1985' 'Spring 1973' 'Spring 1984'
#  'Spring 1982' 'Spring 1992' 'Winter 1993' 'Summer 2006' 'Fall 1985'
#  'Winter 1991' 'Spring 1987' 'Spring 2006' 'Summer 1991' 'Winter 1987'
#  'Winter 1997' 'Winter 1995' 'Spring 1988' 'Summer 1987' 'Winter 1983'
#  'Spring 1980' 'Winter 1990' 'Spring 1976' 'Fall 1984' 'Fall 1991'
#  'Summer 1977' 'Fall 1982' 'Fall 1988' 'Summer 1994' 'Spring 1990'
#  'Fall 1986' 'Summer 1982' 'Spring 2007' 'Fall 1981' 'Summer 1984'
#  'Fall 1971' 'Fall 1977' 'Spring 1967' 'Spring 1981' 'Summer 1975'
#  'Fall 2006' 'Summer 1996' 'Fall 1978' 'Summer 1965' 'Winter 1970'
#  'Fall 1965' 'Winter 2007' 'Winter 1989' 'Fall 1974' 'Fall 1980'
#  'Winter 1976' 'Summer 2007' 'Summer 1980' 'Fall 2007' 'Summer 1983'
#  'Fall 1975' 'Spring 1977' 'Fall 1983' 'Spring 1975' 'Winter 2008'
#  'Winter 1980' 'Spring 1983' 'Winter 1974' 'Fall 1987' 'Summer 1990'
#  'Summer 1972' 'Winter 1982' 'Spring 1970' 'Fall 1972' 'Fall 1969'
#  'Summer 1981' 'Winter 1981' 'Winter 1985' 'Winter 1978' 'Winter 1975'
#  'Winter 1988' 'Fall 1966' 'Winter 1972' 'Winter 1977' 'Winter 1984'
#  'Fall 1963' 'Winter 1967' 'Spring 1972' 'Winter 1963' 'Fall 1976'
#  'Summer 1992' 'Spring 1974' 'Spring 2008' 'Spring 1968' 'Summer 1988'
#  'Winter 1969' 'Summer 1978' 'Fall 2009' 'Fall 2008' 'Summer 2008'
#  'Spring 2009' 'Summer 1986' 'Winter 1971' 'Winter 2009' 'Fall 1990'
#  'Spring 1971' 'Fall 1970' 'Fall 1968' 'Spring 2010' 'Spring 1969'
#  'Summer 2009' 'Winter 2010' 'Summer 1976' 'Summer 2010' 'Winter 1968'
#  'Summer 1979' 'Fall 2010' 'Fall 2011' 'Spring 2011' 'Winter 2011'
#  'Summer 2011' 'Spring 1965' 'Spring 2012' 'Summer 1989' 'Fall 1967'
#  'Winter 2012' 'Spring 1966' 'Fall 2013' 'Summer 1974' 'Spring 1964'
#  'Winter 1966' 'Summer 2012' 'Fall 2012' 'Summer 2013' 'Spring 2013'
#  'Winter 1964' 'Summer 1966' 'Winter 1965' 'Summer 1964' 'Winter 2013'
#  'Spring 1961' 'Summer 1962' 'Winter 2014' 'Summer 1967' 'Winter 2015'
#  'Fall 2014' 'Spring 2015' 'Spring 2014' 'Summer 2014' 'Summer 2015'
#  'Summer 2018' 'Summer 1970' 'Fall 2015' 'Spring 2017' 'Winter 2016'
#  'Spring 2016' 'Winter 2017' 'Summer 2016' 'Fall 2016' 'Spring 2018'
#  'Fall 2017' 'Winter 2019' 'Summer 2019' 'Summer 2017' 'Winter 2021'
#  'Winter 2018' 'Summer 2021' 'Spring 2019' 'Winter 2020' 'Fall 2018'
#  'Fall 2019' 'Summer 2020' 'Fall 2020' 'Spring 2020' 'Fall 2021'
#  'Spring 2021']
#
# Producers: ['Bandai Visual' 'Sunrise, Bandai Visual' 'Victor Entertainment' ...
#  'flying DOG, Hakuhodo DY Music & Pictures' 'Bandai Spirits'
#  'Bushiroad, Bit grooove promotion']
#
# Licensors: ['Funimation, Bandai Entertainment' 'Sony Pictures Entertainment'
#  'Funimation, Geneon Entertainment USA' 'Unknown'
#  'VIZ Media, Sentai Filmworks' 'VIZ Media, Discotek Media' 'Funimation'
#  'VIZ Media' 'Funimation, 4Kids Entertainment' 'Nozomi Entertainment'
#  'Geneon Entertainment USA' 'ADV Films, Netflix' 'Manga Entertainment'
#  'Media Blasters, NYAV Post' 'ADV Films, Aniplex of America'
#  'Media Blasters'
#  'Funimation, Bandai Entertainment, Geneon Entertainment USA' 'AnimEigo'
#  'ADV Films, Sentai Filmworks'
#  'Sentai Filmworks, Geneon Entertainment USA' 'ADV Films'
#  'Bandai Entertainment' 'ADV Films, Funimation'
#  'ADV Films, Discotek Media' 'Discotek Media, Geneon Entertainment USA'
#  'Sentai Filmworks' 'ADV Films, Funimation, Kadokawa Pictures USA'
#  'Nozomi Entertainment, Bandai Entertainment'
#  'Bandai Entertainment, NYAV Post'
#  'ADV Films, Sentai Filmworks, Discotek Media'
#  'Nozomi Entertainment, Geneon Entertainment USA'
#  'Funimation, Aniplex of America'
#  'Media Blasters, Geneon Entertainment USA'
#  'Media Blasters, Discotek Media, Tokyopop' '4Kids Entertainment'
#  'Funimation, Sentai Filmworks' 'Nozomi Entertainment, Maiden Japan'
#  'Central Park Media' 'GKIDS'
#  'Bandai Entertainment, Sentai Filmworks, Discotek Media'
#  'Flatiron Film Company, Geneon Entertainment USA' 'Urban Vision'
#  'Funimation, Tokyopop' 'Bandai Entertainment, Discotek Media'
#  'Walt Disney Studios, GKIDS' 'NuTech Digital'
#  'Funimation, Central Park Media'
#  'Aniplex of America, Manga Entertainment'
#  'Aniplex of America, Geneon Entertainment USA' 'Adult Source Media'
#  'Central Park Media, Discotek Media' 'SoftCel Pictures'
#  'ADV Films, Nozomi Entertainment' 'Media Blasters, SoftCel Pictures'
#  'Funimation, Synch-Point' 'Nozomi Entertainment, NYAV Post'
#  'Nelvana, NIS America, Inc., Geneon Entertainment USA'
#  'Funimation, Crunchyroll' 'Discotek Media, Tokyopop' 'Tokyopop'
#  'Bandai Visual USA' 'VIZ Media, Flatiron Film Company' 'Discotek Media'
#  'Media Blasters, Maiden Japan'
#  'ADV Films, Media Blasters, Discotek Media' 'Maiden Japan'
#  'Bandai Entertainment, Sentai Filmworks' 'Anime Midstream'
#  'Nelvana, Discotek Media' 'Nozomi Entertainment, Discotek Media'
#  'Sentai Filmworks, Synch-Point' 'Central Park Media, Maiden Japan'
#  'Sentai Filmworks, Urban Vision' 'Media Blasters, Discotek Media'
#  'Bandai Entertainment, Central Park Media'
#  'Nelvana, Discotek Media, Geneon Entertainment USA' 'Walt Disney Studios'
#  'Media Blasters, Central Park Media, Discotek Media'
#  'GKIDS, Manga Entertainment' 'Nozomi Entertainment, Central Park Media'
#  'Bandai Entertainment, Manga Entertainment'
#  '4Kids Entertainment, Flatiron Film Company'
#  'VIZ Media, 4Kids Entertainment'
#  '4Kids Entertainment, Warner Bros. Pictures'
#  'ADV Films, VIZ Media, DiC Entertainment'
#  'VIZ Media, Geneon Entertainment USA'
#  'Funimation, Central Park Media, Enoki Films'
#  'Discotek Media, Urban Vision' 'ADV Films, Maiden Japan'
#  'Saban Entertainment, Flatiron Film Company'
#  'Bandai Entertainment, Bandai Visual USA'
#  'ADV Films, Central Park Media, Sentai Filmworks'
#  'Funimation, Manga Entertainment'
#  'Nozomi Entertainment, Crimson Star Media'
#  'Nozomi Entertainment, Media Blasters' 'Synch-Point'
#  'Sentai Filmworks, Manga Entertainment'
#  'Nozomi Entertainment, Media Blasters, NYAV Post'
#  'Bandai Entertainment, Media Blasters' 'ADV Films, AnimEigo'
#  'Super Techno Arts' 'ADV Films, Manga Entertainment'
#  'Tokyopop, Maiden Japan' 'Kitty Media' 'Media Blasters, Kitty Media'
#  'Sony Pictures Entertainment, GKIDS' 'ADV Films, Central Park Media'
#  'Funimation, Bandai Entertainment, Kadokawa Pictures USA'
#  'Flatiron Film Company' 'ADV Films, Funimation, NYAV Post'
#  'Funimation, Media Blasters' 'ADV Films, Funimation, OLM Digital'
#  'Anchor Bay Films' 'Sentai Filmworks, Crunchyroll'
#  'Discotek Media, Manga Entertainment' "Brain's Base, Discotek Media"
#  'Nozomi Entertainment, Kadokawa Pictures USA' 'Bandai'
#  'Discotek Media, Bandai Visual USA' 'Funimation, Kadokawa Pictures USA'
#  'Eleven Arts, DreamWorks'
#  'Maiden Japan, Manga Entertainment, Bandai Visual USA'
#  'Geneon Universal Entertainment, Funimation'
#  'Maiden Japan, Geneon Entertainment USA' 'AnimEigo, Discotek Media'
#  '4Kids Entertainment, Warner Bros. Japan'
#  '4Kids Entertainment, Miramax Films' 'Saban Entertainment'
#  'ADV Films, Discotek Media, Shout! Factory'
#  'Media Blasters, Central Park Media'
#  'Funimation, Sentai Filmworks, Geneon Entertainment USA' 'Shout! Factory'
#  'Funimation, Discotek Media, Geneon Entertainment USA'
#  'ADV Films, DiC Entertainment, Flatiron Film Company'
#  'Discotek Media, Saban Entertainment'
#  'Central Park Media, Critical Mass Video'
#  'Media Blasters, Sentai Filmworks' 'Warner Bros. Japan'
#  'ADV Films, SoftCel Pictures' 'NuTech Digital, Critical Mass Video'
#  'Critical Mass Video' 'Funimation, Discotek Media'
#  'Sony Pictures Entertainment, Discotek Media'
#  'ADV Films, Central Park Media, Discotek Media'
#  '4Kids Entertainment, The Pokemon Company International'
#  'Bandai Entertainment, Media Blasters, Bandai Visual USA'
#  'VIZ Media, 4Kids Entertainment, The Pokemon Company International'
#  'VIZ Media, The Pokemon Company International' 'Voyager Entertainment'
#  'Nelvana' 'Hasbro'
#  'ADV Films, Bandai Entertainment, Discotek Media, Crunchyroll'
#  'Enoki Films'
#  'Bandai Entertainment, Discotek Media, NYAV Post, Bandai Visual USA'
#  'ADV Films, Media Blasters' '4Kids Entertainment, Discotek Media'
#  'Geneon Universal Entertainment'
#  'VIZ Media, Media Blasters, Sentai Filmworks, Geneon Entertainment USA'
#  'Kadokawa Pictures USA' 'Bandai Entertainment, Maiden Japan' 'JapanAnime'
#  'Nozomi Entertainment, Bandai Visual USA' 'Enoki Films, Urban Vision'
#  'ADV Films, Bandai Entertainment, Aniplex of America'
#  'Maiden Japan, Bandai Visual USA'
#  'Bandai Entertainment, Discotek Media, Bandai Visual USA'
#  'Warner Bros. Pictures' 'NuTech Digital, Kitty Media'
#  'Media Blasters, Discotek Media, NYAV Post'
#  'Walt Disney Studios, Hasbro, Saban Entertainment'
#  '4Kids Entertainment, Enoki Films, Discotek Media'
#  'Media Blasters, Discotek Media, NYAV Post, Manga Entertainment'
#  'Saban Brands' 'Pioneer LDC' 'Aniplex of America' 'Capcom'
#  'The Pokemon Company International'
#  'Sentai Filmworks, Saban Entertainment' 'ADV Films, Warner Bros. Japan'
#  'Central Park Media, NYAV Post' 'Cinelicious Pics' 'NIS America, Inc.'
#  'Central Park Media, Sentai Filmworks, Discotek Media'
#  'NuTech Digital, Central Park Media' 'NuTech Digital, Adult Source Media'
#  'Funimation, NYAV Post' 'Pied Piper'
#  'Bandai Entertainment, Sentai Filmworks, NYAV Post' 'NYAV Post'
#  'Anchor Bay Films, Manga Entertainment'
#  'Funimation, Warner Bros. Japan, GKIDS'
#  'Nozomi Entertainment, Bandai Entertainment, NYAV Post'
#  'Marvel Entertainment' '4Kids Entertainment, Nintendo of America'
#  'Funimation, Nozomi Entertainment' 'Dentsu Entertainment USA'
#  'NYAV Post, Pied Piper' 'NYAV Post, GKIDS' 'Sentai Filmworks, NYAV Post'
#  'Bandai Entertainment, Aniplex of America'
#  'NIS America, Inc., Aniplex of America' 'Konami, 4Kids Entertainment'
#  'Bandai, Sentai Filmworks' 'VIZ Media, NYAV Post' 'Eleven Arts'
#  'Cookie Jar Entertainment' 'VIZ Media, Warner Bros. Pictures' 'Active'
#  'Ketchup Entertainment' 'Discotek Media, Crunchyroll' 'Kadokawa'
#  'Funimation, Discotek Media, Crunchyroll' 'Crunchyroll' 'Netflix'
#  'Ponycan USA' 'Eleven Arts, NYAV Post' 'bilibili'
#  'Haoliners Animation League' 'Aniplex of America, Crunchyroll' 'feel.'
#  'B.CMAY PICTURES' 'Funimation, NBCUniversal Entertainment Japan'
#  'Bandai Namco Games' 'Eleven Arts, Ponycan USA'
#  'Eleven Arts, Shout! Factory' 'Warner Bros. Japan, Crunchyroll'
#  'Sentai Filmworks, Ponycan USA' 'Discotek Media, Ponycan USA'
#  'Media Bank' 'Sentai Filmworks, Kadokawa' 'iQIYI']
#
# Studios: ['Sunrise' 'Bones' 'Madhouse' ... 'Fanworks, Space Neko Company' 'OZ'
#  'Studio Kafka']
#
# Source: ['Original' 'Manga' 'Light novel' 'Game' 'Visual novel' '4-koma manga'
#  'Novel' 'Unknown' 'Other' 'Picture book' 'Web manga' 'Music' 'Radio'
#  'Book' 'Card game' 'Digital manga']
#
# Duration: ['24 min. per ep.' '1 hr. 55 min.' '25 min. per ep.' '23 min. per ep.'
#  '27 min. per ep.' '24 min.' '22 min. per ep.' '1 hr. 44 min.'
#  '1 hr. 27 min.' '1 hr. 22 min.' '30 min. per ep.' '1 hr. 31 min.'
#  '2 hr. 4 min.' '1 hr. 45 min.' '52 min.' '1 hr. 59 min.' '2 hr.'
#  '21 min. per ep.' '14 min. per ep.' '12 min. per ep.' '34 min. per ep.'
#  '46 min. per ep.' '1 hr. 37 min.' '20 min. per ep.' '2 hr. 15 min.'
#  '26 min. per ep.' '28 min. per ep.' '21 min.' '46 min.' '15 min. per ep.'
#  '2 hr. 5 min.' '29 min. per ep.' '33 min. per ep.' '1 hr. 24 min.'
#  '48 min.' '1 hr. 19 min.' '25 min.' '1 hr. 30 min.' '1 hr. 1 min.'
#  '4 min. per ep.' '7 min. per ep.' '1 hr. 46 min.' '18 min. per ep.'
#  '1 hr. 41 min.' '11 min. per ep.' '13 min. per ep.' '55 min.'
#  '1 hr. 21 min.' '1 hr. 2 min.' '37 min. per ep.' '42 min. per ep.'
#  '37 min.' '19 min.' '1 hr. 33 min.' '1 hr. 14 min.' '50 min.' '42 min.'
#  '1 hr. 20 min.' '45 min. per ep.' '1 hr. 39 min.' '1 hr. 38 min.'
#  '26 min.' '1 hr. 35 min.' '1 hr. 34 min.' '28 min.' '39 min. per ep.'
#  '40 min.' '5 min. per ep.' '1 hr. 32 min.' '2 hr. 12 min.'
#  '1 hr. 36 min.' '36 min. per ep.' '30 min.' '1 hr. 49 min.'
#  '1 hr. 26 min.' '1 hr. 25 min.' '1 hr. 6 min.' '1 hr. 42 min.'
#  '1 hr. 43 min.' '1 hr. 23 min.' '15 min.' '51 min.' '31 min. per ep.'
#  '2 hr. 6 min.' '1 hr. 57 min.' '1 hr. 28 min.' '8 min. per ep.'
#  '1 hr. 51 min.' '22 min.' '6 min.' '1 hr. 15 min.' '32 min.'
#  '6 min. per ep.' '23 min.' '1 hr. 17 min.' '31 min.' '35 min. per ep.'
#  '1 min. per ep.' '3 min. per ep.' '20 min.' '10 min.' '2 hr. 20 min.'
#  '54 min. per ep.' '16 min. per ep.' '1 hr. 7 min.' '44 min.'
#  '1 hr. 12 min.' '27 min.' '17 min.' '29 min.' '50 min. per ep.'
#  '1 hr. 40 min.' '48 min. per ep.' '1 hr.' '35 min.' '1 hr. 5 min.'
#  '49 min.' '17 min. per ep.' '10 min. per ep.' '33 min.' '43 min. per ep.'
#  '59 min.' '9 min. per ep.' '1 hr. 11 min.' '45 min.' '41 min.'
#  '1 hr. 10 min.' '11 min.' '53 min.' '32 min. per ep.' '5 min.' '47 min.'
#  '4 min.' '1 hr. 58 min.' '2 hr. 1 min.' '54 min.' '1 hr. 3 min.'
#  '40 min. per ep.' '1 hr. 48 min.' '1 hr. 18 min.' '47 min. per ep.'
#  '2 hr. 16 min.' '43 min.' '52 min. per ep.' '56 min.' '58 min.'
#  '2 hr. 19 min.' '51 min. per ep.' '2 hr. 8 min.' '2 hr. 10 min.'
#  '41 min. per ep.' '58 min. per ep.' '1 hr. 50 min.' '1 hr. 47 min.'
#  '12 min.' '1 hr. 13 min.' '38 min. per ep.' '1 hr. 5 min. per ep.'
#  '39 min.' '1 hr. 9 min.' '1 hr. per ep.' '3 min.' '2 hr. 11 min.'
#  '34 min.' '57 min.' '1 hr. 52 min.' '2 min. per ep.' '16 min.' '13 min.'
#  '38 min.' '1 hr. 17 min. per ep.' '8 min.' '1 hr. 38 min. per ep.'
#  '1 hr. 7 min. per ep.' '55 min. per ep.' '1 hr. 29 min.' '1 hr. 56 min.'
#  '53 min. per ep.' '1 min.' '9 min.' '7 min.' '1 hr. 35 min. per ep.'
#  '1 hr. 30 min. per ep.' '49 min. per ep.' '2 hr. 41 min.' '2 hr. 40 min.'
#  '14 min.' '1 hr. 8 min.' '57 min. per ep.' '2 min.' '1 hr. 53 min.'
#  '18 min.' '2 hr. 21 min.' '2 hr. 33 min.' '1 hr. 52 min. per ep.'
#  '1 hr. 4 min.' '2 hr. 32 min.' '2 hr. 30 min.' '2 hr. 43 min.'
#  '2 hr. 2 min.' '36 min.' 'Unknown' '1 hr. 16 min.' '1 hr. 54 min.'
#  '44 min. per ep.' '12 sec.' '19 min. per ep.' '52 sec.' '30 sec. per ep.'
#  '1 hr. 2 min. per ep.' '22 sec. per ep.' '2 hr. 3 min.' '40 sec. per ep.'
#  '2 hr. 42 min.' '32 sec.' '1 hr. 14 min. per ep.' '39 sec. per ep.'
#  '2 hr. 28 min.' '2 hr. 27 min.' '2 hr. 7 min.' '15 sec. per ep.'
#  '30 sec.' '1 hr. 11 min. per ep.' '1 hr. 16 min. per ep.'
#  '53 sec. per ep.' '38 sec.' '29 sec.' '35 sec.' '33 sec. per ep.'
#  '2 hr. 36 min.' '34 sec. per ep.' '2 hr. 17 min.' '1 hr. 15 min. per ep.'
#  '24 sec. per ep.' '37 sec. per ep.' '31 sec. per ep.' '29 sec. per ep.'
#  '1 hr. 36 min. per ep.' '31 sec.' '41 sec.' '45 sec. per ep.'
#  '35 sec. per ep.' '15 sec.' '49 sec. per ep.' '17 sec.' '54 sec.'
#  '2 hr. 14 min.' '16 sec.' '41 sec. per ep.' '27 sec.' '42 sec.' '14 sec.'
#  '26 sec. per ep.' '36 sec.' '37 sec.' '58 sec. per ep.'
#  '1 hr. 24 min. per ep.' '50 sec.' '45 sec.' '33 sec.' '32 sec. per ep.'
#  '55 sec.' '57 sec.' '16 sec. per ep.' '40 sec.' '10 sec.' '46 sec.'
#  '7 sec.' '49 sec.' '39 sec.' '51 sec. per ep.' '57 sec. per ep.'
#  '10 sec. per ep.' '44 sec. per ep.' '3 sec.' '2 hr. 47 min.' '25 sec.'
#  '36 sec. per ep.' '20 sec. per ep.' '42 sec. per ep.' '19 sec.'
#  '18 sec. per ep.' '44 sec.' '20 sec.' '51 sec.' '28 sec.'
#  '46 sec. per ep.' '56 sec. per ep.' '34 sec.' '50 sec. per ep.' '58 sec.'
#  '21 sec.' '13 sec.' '54 sec. per ep.' '23 sec.' '22 sec.'
#  '21 sec. per ep.' '25 sec. per ep.' '12 sec. per ep.' '38 sec. per ep.'
#  '14 sec. per ep.' '6 sec. per ep.' '23 sec. per ep.' '47 sec.'
#  '1 hr. 9 min. per ep.' '24 sec.' '28 sec. per ep.' '43 sec. per ep.'
#  '1 hr. 27 min. per ep.' '48 sec.' '6 sec.' '43 sec.' '55 sec. per ep.']
#
# Rating: ['R - 17+ (violence & profanity)' 'PG-13 - Teens 13 or older'
#  'PG - Children' 'R+ - Mild Nudity' 'G - All Ages' 'Rx - Hentai' 'Unknown']

# %% [markdown]
# For the date data we can change them into Year, month and day in number. Nevertheless I prefer to use a 2 dimensional representations for month and day, this can represent the cyclic nature of the months and days of the weeks rather than just the number itself.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Finally we can see that the duration can also be represented by the number of minutes. All this transformations will be done at the feautre engineering section.

# %%
data['Popularity']
# Out:
# 0           39
# 1          518
# 2          201
# 3         1467
# 4         4369
#          ...
# 17557    13116
# 17558    17562
# 17559    17558
# 17560    17565
# 17561    17563
# Name: Popularity, Length: 17562, dtype: int64

# %% [markdown]
# # Clean dataset
#
# We have seen before that we have no nan data nor duplicated data. But we do have some features with 'unknown' data. We need to do the following:
#
# * N-Scores:
#     * First change type from string to float
#     * Impute the unknown scores by a linear interpolation.
# * Scores: (First change type from string to float) Recalculate the scores based on the information obtained.
# * Premiered and Licensors: Remove this features (More than 70% of the information is unknown)
# * Aired, keep years only since this might be the most relevant data (If we want to analyze performance of launching an Anime, months and days might be more relevant).
# * For the Duration and Rating Unknown values I took the average value.
# * For categorical data the unknown values can be a category by itself.
# * Impute the unknown ranks as the average rank (not good or bad since is in the middle) and add an unkown rank feature (1 means unknown and 0 that we have a known feature)

# %%
import numpy as np
# Change type of scores 
data.replace({'Score': 'Unknown'}, 'NaN', inplace = True)
data['Score'] = data['Score'].astype(float)

# All scores (1 - 10)
score_cols = []
for ii in range(10):
    feature = 'Score-' + str(ii + 1)
    score_cols.append(feature)
    data.replace({feature: 'Unknown'}, 'NaN', inplace = True)
    data[feature] = data[feature].astype(float)

# Calculate values for unknown scores
data.loc[:, score_cols] = data[score_cols].interpolate(method='linear', axis=1, limit_direction='both')

# Recalculate the scores based on the imputated scores
data.loc[:, 'Score'] = (data[score_cols]*(1+np.arange(10))).sum(axis = 1)/((data[score_cols]).sum(axis = 1))

# Replace unknown scores to 5 (not good but not bad enough) and unknown score-i to 0 (no votes)
data.replace({'Score': np.nan}, 5, inplace = True)
for scorecol in score_cols:
    data.replace({scorecol: np.nan}, 0, inplace = True)

# Remove premiered and licensors features
data.drop(columns= {'Licensors', 'Premiered'}, inplace = True)

# Create OHE for categorical data
    # First for the genres (this are separated by commas in each row we need first each genre)
all_genres = set(genre.strip() for sublist in data['Genres'].str.split(',') for genre in sublist)
for genre in all_genres:
    data[genre] = data['Genres'].apply(lambda x: 1 if genre in x else 0)
data.drop(columns = 'Genres', inplace = True)

# %% [markdown]
# For 'Aired' feature we will use only the year. If only one year is shown we will consider this the same year of finishing. If we have something like 'Jan 23, 1992, ?' we consider '?' as still in air. We will use the current year as the last year

# %%
import re
from datetime import datetime
# Current year
current_year = datetime.now().year

def extract_years(date_str):
    current_year = datetime.now().year
    date_str = date_str.replace('?', str(current_year))
    years = re.findall(r'\d{4}', date_str)
    
    if len(years) == 1:
        return int(years[0]), int(years[0])
    elif len(years) == 2:
        return int(years[0]), int(years[1])
    else:
        return None, None  # Handle cases where no valid year is found
    
data['Initial Year'], data['Last Year'] = zip(*data['Aired'].apply(extract_years))

data.replace({'Initial Year': np.nan}, data['Initial Year'].mean(skipna = True), inplace = True)
data.replace({'Last Year': np.nan}, data['Last Year'].mean(skipna = True), inplace = True)

data.drop(columns= 'Aired', inplace=True)
data[['Initial Year', 'Last Year']]
# Out:
#        Initial Year    Last Year
# 0       1998.000000  1999.000000
# 1       2001.000000  2001.000000
# 2       1998.000000  1998.000000
# 3       2002.000000  2002.000000
# 4       2004.000000  2005.000000
# ...             ...          ...
# 17557   2021.000000  2024.000000
# 17558   2021.000000  2024.000000
# 17559   2021.000000  2024.000000
# 17560   2005.127166  2005.600185
# 17561   2021.000000  2024.000000
#
# [17562 rows x 2 columns]

# %%
# Remove Unknown values for the average value in Episodes
data.replace({'Episodes': 'Unknown'}, 'NaN', inplace = True)
data['Episodes'] = data['Episodes'].astype(float)

data.replace({'Episodes': np.nan}, data['Episodes'].mean(skipna = True), inplace = True)
data['Episodes']
# Out:
# 0        26.000000
# 1         1.000000
# 2        26.000000
# 3        26.000000
# 4        52.000000
#            ...
# 17557    11.525519
# 17558    11.525519
# 17559    11.525519
# 17560    11.525519
# 17561    11.525519
# Name: Episodes, Length: 17562, dtype: float64

# %%
# Transform 'Duration' data into minutes only
def convert_to_minutes(duration_str):
    # Regular expressions to capture hours and minutes
    hours_pattern = r'(\d+)\s*hr'
    minutes_pattern = r'(\d+)\s*min'
    
    # Find hours and minutes in the string
    hours_match = re.search(hours_pattern, duration_str)
    minutes_match = re.search(minutes_pattern, duration_str)
    unknown_match = re.search('Unknown', duration_str)

    # Convert to minutes
    total_minutes = 0
    
    if hours_match:
        hours = int(hours_match.group(1))
        total_minutes += hours * 60
    
    if minutes_match:
        minutes = int(minutes_match.group(1))
        total_minutes += minutes
    if unknown_match:
        total_minutes = np.nan

    return total_minutes

# Apply the function to the DataFrame
data.loc[:, 'Duration'] = data['Duration'].apply(convert_to_minutes)
data.loc[:, 'Duration'] = data['Duration'].astype(float)

# Get unknown duration data to be the mean rank
data.replace({'Duration': np.nan}, data['Duration'].mean(skipna = True), inplace = True)
# Out:
# C:\Users\gilbe\AppData\Local\Temp\ipykernel_12452\1854820143.py:32: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Duration': np.nan}, data['Duration'].mean(skipna = True), inplace = True)

# %% [markdown]
# # Feature engineering

# %% [markdown]
# Apply OHE and get a dataset without the names of the movies

# %%
# Now the categorical data with OHE

# One Hot Encoding the rest of categorical data
columns = data.columns
categorical_features = columns[data.dtypes == object]
data = pd.get_dummies(data, columns = categorical_features[1:])

# Creat dataset without names
columns = data.columns
data_model = data[columns[1:]]
columns = data_model.columns
print(f"Number of non binary features: {len(columns) - len(columns[data_model.dtypes == bool])}")
data_model
# Out:
# Number of non binary features: 67
#           Score   Episodes    Duration  Popularity  Members  Favorites  \
# 0      8.740248  26.000000   24.000000          39  1251960      61971
# 1      8.390985   1.000000  115.000000         518   273145       1174
# 2      8.215289  26.000000   24.000000         201   558913      12944
# 3      7.216657  26.000000   25.000000        1467    94683        587
# 4      6.892115  52.000000   23.000000        4369    13224         18
# ...         ...        ...         ...         ...      ...        ...
# 17557  5.500000  11.525519   24.532839       13116      354          6
# 17558  5.000000  11.525519   24.532839       17562     7010         70
# 17559  5.500000  11.525519   24.532839       17558    11309         48
# 17560  5.000000  11.525519   24.532839       17565     1386          2
# 17561  5.000000  11.525519   24.532839       17563      310          0
#
#        Watching  Completed  On-Hold  Dropped  ...  Ranked_9987.0  \
# 0        105808     718161    71513    26678  ...          False
# 1          4143     208333     1935      770  ...          False
# 2         29113     343492    25465    13925  ...          False
# 3          4300      46165     5121     5378  ...          False
# 4           642       7314      766     1108  ...          False
# ...         ...        ...      ...      ...  ...            ...
# 17557         0          0        0        0  ...          False
# 17558        14          0       14        0  ...          False
# 17559         3          0        0        0  ...          False
# 17560        13          2        2        1  ...          False
# 17561         4          0        1        1  ...          False
#
#        Ranked_9989.0  Ranked_9991.0  Ranked_9992.0  Ranked_9993.0  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 17557          False          False          False          False
# 17558          False          False          False          False
# 17559          False          False          False          False
# 17560          False          False          False          False
# 17561          False          False          False          False
#
#        Ranked_9996.0  Ranked_9997.0  Ranked_9998.0  Ranked_9999.0  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 17557          False          False          False          False
# 17558          False          False          False          False
# 17559          False          False          False          False
# 17560          False          False          False          False
# 17561          False          False          False          False
#
#        Ranked_Unknown
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 17557            True
# 17558            True
# 17559            True
# 17560            True
# 17561            True
#
# [17562 rows x 15460 columns]

# %% [markdown]
# With this we finish cleaning the dataset with a total of 17562 rows and 15460 columns. From this, 15393 are booleans corresponding to the categorical data. We will apply PCA mainly to this features to reduce the categorical data to 33 features (just to have a total of 100 features).

# %% [markdown]
# Apply PCA only to the boolean features

# %%
# Position again the target column to the end of the data
from sklearn.decomposition import PCA

pca_enc = PCA(n_components = 33)
pca_num = PCA(n_components = 33)

data_model.reset_index(inplace = True)
data_model.drop(columns = 'index', inplace = True)
columns = data_model.columns
red_cat_data = pca_enc.fit_transform(data_model[columns[data_model.dtypes == bool]])
pca_data = pd.concat([data_model[columns[data_model.dtypes != bool]], pd.DataFrame(red_cat_data)], axis = 1)
pca_data_np = pca_data.to_numpy()
# Out:
# C:\Users\gilbe\AppData\Local\Temp\ipykernel_12452\1379511651.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_model.drop(columns = 'index', inplace = True)

# %%
# Perform standardization of the features
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
data_std = std_scaler.fit_transform(data_model)

# %% [markdown]
# ## Customer segmentation
#
# Here we would like to get a segmentation of customers, understanding which groups exists, their size and how they are related. For this we will use a couple of techniques such as K-means, HAC and DBSCAN. To evaluate performance of the clustering we will use the silhouette score.

# %% [markdown]
# ## K-means

# %%
from tqdm import tqdm
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.metrics import pairwise_distances

distance_matrix = pairwise_distances(pca_data_np)
np.fill_diagonal(distance_matrix, 0) # Remove computational errors of distances

# %%
from tqdm import tqdm
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.metrics import pairwise_distances

distance_matrix = pairwise_distances(pca_data_np)
np.fill_diagonal(distance_matrix, 0) # Remove computational errors of distances

n_clusters = np.arange(10, 50)
silhouette = []
for n_clust in tqdm(n_clusters):
    sil = 0
    for jj in range(5):
        kmeans = KMeans(n_clusters = n_clust, init = 'k-means++')
        kmeans.fit(pca_data_np)
        sil += silhouette_score(distance_matrix, kmeans.labels_, metric='precomputed')
    silhouette.append(sil/5)

plt.plot(n_clusters, silhouette, label = 'Numerical data')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.legend()
plt.savefig('Images/Anime Recommendation/Kmeans.png')
# Out:
# 100%|██████████| 40/40 [06:43<00:00, 10.08s/it]

# %% [markdown]
# By the silhouette score we can see that a clustering of 2 classes has a silhouette score of aproximately 0.6 which suggests that the clusters are well separated.

# %% [markdown]
# ## Hierarchical Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

n_clusters = np.arange(10, 50)
silhouette = []

for n_clust in tqdm(n_clusters):
    sil = 0
    for ii in range(5):
        HAC = AgglomerativeClustering(n_clusters = n_clust, linkage = 'ward', metric = 'euclidean')
        HAC.fit(pca_data_np)
        sil += silhouette_score(distance_matrix, HAC.labels_, metric='precomputed')
    silhouette.append(sil/5)

plt.plot(n_clusters, silhouette, label = 'Numerical data')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.legend()
plt.savefig('Images/Anime Recommendation/HAC.png')
# Out:
# 100%|██████████| 40/40 [1:45:45<00:00, 158.65s/it]

# %% [markdown]
# ## DBSCAN
#
# Here we need to decide for an optimal N and $\epsilon$ we will use grid search for this. But before, we will compute the maximum distance of nearest neighbors to get an idea of an optimal $\epsilon$ and $N$

# %%
from sklearn.neighbors import NearestNeighbors

# Compute the k-nearest neighbors
neigh = NearestNeighbors(n_neighbors=100)
nbrs = neigh.fit(data_model)
distances, indices = nbrs.kneighbors(data_model)

# Sort distances
distances = np.sort(distances, axis=0)

#Plot distances
plt.plot(distances)
plt.ylabel('N-neighbor distance')
plt.xlabel('Datapoint')
plt.show()

# %% [markdown]
# Lets zoom before the elbow

# %%
#Plot distances
plt.plot(distances[:14000])
plt.ylabel('N-neighbor distance')
plt.xlabel('Datapoint')
plt.show()

# %% [markdown]
# We can see most of the data points has neighbors with distances are below 2500, lets use a grid search to find the best parameters. Since this is a recommendation system we would like to have at least lets say 10 clusters. Otherwise we will guess we have only 2 types of customers which could by highly rare.

# %%
from sklearn.cluster import DBSCAN

epsilons = np.arange(1000, 17000, 250)
min_samples = np.arange(2, 10)

best_score = -1
best_params = {'eps': None, 'min_samples': None}

sil_scores = np.ones((len(epsilons), len(min_samples)))*-1
num_of_labels = np.zeros((len(epsilons), len(min_samples)))
ii = 0
for eps in epsilons:
    num_labels = 20
    jj = 0
    for min_sample in min_samples:
        #Increasing the number of min_sample reduces the number of labels,
        #if we want at least 10 labels we can stop increasing min_sample 
        #if we obtain less than 10 labels.
        if num_labels >= 10:
            dbscan = DBSCAN(eps=eps, min_samples=min_sample, metric = 'euclidean')
            labels = dbscan.fit_predict(pca_data_np)
            num_labels = len(set(labels))
            
        if num_labels >=10:
            num_of_labels[ii, jj] = num_labels
            #Calculate Silhouette_score
            score = silhouette_score(distance_matrix, labels, metric = 'precomputed')
            sil_scores[ii, jj] = score
            print(f"eps = {eps}, min_samples = {min_sample} - Silhouette Score: {score}, # of labels: {len(set(labels))}")

            if score > best_score:
                best_score = score
                best_params['eps'] = eps
                best_params['min_samples'] = min_sample
        jj +=1 
    ii+=1

print(f"Best Params: {best_params} with Silhouette Score: {best_score}")
# Out:
# eps = 1000, min_samples = 2 - Silhouette Score: -0.13829173170559794, # of labels: 183
# eps = 1000, min_samples = 3 - Silhouette Score: -0.008707086981697323, # of labels: 66
# eps = 1000, min_samples = 4 - Silhouette Score: 0.0043767133929311095, # of labels: 31
# eps = 1000, min_samples = 5 - Silhouette Score: 0.30173617395353036, # of labels: 17
# eps = 1000, min_samples = 6 - Silhouette Score: 0.26645820211303306, # of labels: 12
# eps = 1000, min_samples = 7 - Silhouette Score: 0.26539072677818576, # of labels: 11
# eps = 1250, min_samples = 2 - Silhouette Score: -0.0056483127687180015, # of labels: 163
# eps = 1250, min_samples = 3 - Silhouette Score: 0.0658254199660711, # of labels: 67
# eps = 1250, min_samples = 4 - Silhouette Score: 0.06872768523059461, # of labels: 34
# eps = 1250, min_samples = 5 - Silhouette Score: 0.2798163602723221, # of labels: 19
# eps = 1250, min_samples = 6 - Silhouette Score: 0.1960961179258615, # of labels: 14
# eps = 1500, min_samples = 2 - Silhouette Score: 0.06972864423401705, # of labels: 130
# eps = 1500, min_samples = 3 - Silhouette Score: 0.08293192565598641, # of labels: 45
# eps = 1500, min_samples = 4 - Silhouette Score: 0.07100062426504304, # of labels: 30
# eps = 1500, min_samples = 5 - Silhouette Score: 0.3334115785215427, # of labels: 25
# eps = 1500, min_samples = 6 - Silhouette Score: 0.2772615580641458, # of labels: 13
# eps = 1750, min_samples = 2 - Silhouette Score: 0.026420852080425942, # of labels: 131
# eps = 1750, min_samples = 3 - Silhouette Score: 0.05104683764351946, # of labels: 45
# eps = 1750, min_samples = 4 - Silhouette Score: 0.047255849123851106, # of labels: 21
# eps = 1750, min_samples = 5 - Silhouette Score: 0.3278502657500818, # of labels: 14
# eps = 1750, min_samples = 6 - Silhouette Score: 0.3283973049306079, # of labels: 15
# eps = 1750, min_samples = 7 - Silhouette Score: 0.3880347929414589, # of labels: 11
# eps = 1750, min_samples = 8 - Silhouette Score: 0.391738528278741, # of labels: 11
# eps = 2000, min_samples = 2 - Silhouette Score: 0.030342181274479293, # of labels: 130
# eps = 2000, min_samples = 3 - Silhouette Score: 0.04720961741252384, # of labels: 49
# eps = 2000, min_samples = 4 - Silhouette Score: 0.28731769638471427, # of labels: 31
# eps = 2000, min_samples = 5 - Silhouette Score: 0.44496080342072103, # of labels: 14
# eps = 2250, min_samples = 2 - Silhouette Score: 0.05881006775372814, # of labels: 117
# eps = 2250, min_samples = 3 - Silhouette Score: 0.2597853059278906, # of labels: 52
# eps = 2250, min_samples = 4 - Silhouette Score: 0.27234937047960367, # of labels: 25
# eps = 2250, min_samples = 5 - Silhouette Score: 0.4177232303198498, # of labels: 24
# eps = 2250, min_samples = 6 - Silhouette Score: 0.4232271997815744, # of labels: 10
# eps = 2500, min_samples = 2 - Silhouette Score: 0.017876390637775776, # of labels: 112
# eps = 2500, min_samples = 3 - Silhouette Score: 0.24362831576812205, # of labels: 44
# eps = 2500, min_samples = 4 - Silhouette Score: 0.24404622905288348, # of labels: 22
# eps = 2500, min_samples = 5 - Silhouette Score: 0.4975537106712024, # of labels: 13
# eps = 2500, min_samples = 6 - Silhouette Score: 0.44368685918153317, # of labels: 15
# eps = 2500, min_samples = 7 - Silhouette Score: 0.4209625325929098, # of labels: 12
# eps = 2750, min_samples = 2 - Silhouette Score: 0.00685966346492861, # of labels: 115
# eps = 2750, min_samples = 3 - Silhouette Score: 0.23402519463156346, # of labels: 46
# eps = 2750, min_samples = 4 - Silhouette Score: 0.23839278112177892, # of labels: 23
# eps = 2750, min_samples = 5 - Silhouette Score: 0.2390537025402517, # of labels: 14
# eps = 3000, min_samples = 2 - Silhouette Score: 0.0008508900664355, # of labels: 113
# eps = 3000, min_samples = 3 - Silhouette Score: 0.33885510746465786, # of labels: 47
# eps = 3000, min_samples = 4 - Silhouette Score: 0.21894892463492246, # of labels: 21
# eps = 3000, min_samples = 5 - Silhouette Score: 0.21971684481572665, # of labels: 14
# eps = 3250, min_samples = 2 - Silhouette Score: -0.019006971508363724, # of labels: 109
# eps = 3250, min_samples = 3 - Silhouette Score: 0.32814131578456984, # of labels: 47
# eps = 3250, min_samples = 4 - Silhouette Score: 0.33667677358282727, # of labels: 24
# eps = 3250, min_samples = 5 - Silhouette Score: 0.2368492602490881, # of labels: 18
# eps = 3250, min_samples = 6 - Silhouette Score: 0.21641614459059583, # of labels: 11
# eps = 3500, min_samples = 2 - Silhouette Score: -0.008038948648771268, # of labels: 106
# eps = 3500, min_samples = 3 - Silhouette Score: 0.3187468689706278, # of labels: 44
# eps = 3500, min_samples = 4 - Silhouette Score: 0.32410543660359753, # of labels: 24
# eps = 3500, min_samples = 5 - Silhouette Score: 0.556197071455848, # of labels: 11
# eps = 3500, min_samples = 6 - Silhouette Score: 0.24490893707267686, # of labels: 11
# eps = 3750, min_samples = 2 - Silhouette Score: -0.012071969976328718, # of labels: 110
# eps = 3750, min_samples = 3 - Silhouette Score: 0.31671626384377227, # of labels: 49
# eps = 3750, min_samples = 4 - Silhouette Score: 0.31942401638747825, # of labels: 25
# eps = 3750, min_samples = 5 - Silhouette Score: 0.5215179455629251, # of labels: 14
# eps = 3750, min_samples = 6 - Silhouette Score: 0.5556354735490054, # of labels: 12
# eps = 3750, min_samples = 7 - Silhouette Score: 0.23821781234392245, # of labels: 10
# eps = 4000, min_samples = 2 - Silhouette Score: -0.015134285618688391, # of labels: 117
# eps = 4000, min_samples = 3 - Silhouette Score: 0.31584284338561475, # of labels: 48
# eps = 4000, min_samples = 4 - Silhouette Score: 0.31634958741291147, # of labels: 25
# eps = 4000, min_samples = 5 - Silhouette Score: 0.5621449982371622, # of labels: 13
# eps = 4250, min_samples = 2 - Silhouette Score: -0.0698188959792314, # of labels: 100
# eps = 4250, min_samples = 3 - Silhouette Score: 0.5499174949217273, # of labels: 43
# eps = 4250, min_samples = 4 - Silhouette Score: 0.5534829100409168, # of labels: 25
# eps = 4500, min_samples = 2 - Silhouette Score: -0.07985547251472314, # of labels: 95
# eps = 4500, min_samples = 3 - Silhouette Score: 0.5528262034871937, # of labels: 38
# eps = 4500, min_samples = 4 - Silhouette Score: 0.5576700798124843, # of labels: 22
# eps = 4500, min_samples = 5 - Silhouette Score: 0.5574591780513246, # of labels: 18
# eps = 4500, min_samples = 6 - Silhouette Score: 0.5591251830636402, # of labels: 10
# eps = 4750, min_samples = 2 - Silhouette Score: -0.09712325866971774, # of labels: 90
# eps = 4750, min_samples = 3 - Silhouette Score: 0.5455493041677408, # of labels: 37
# eps = 4750, min_samples = 4 - Silhouette Score: 0.5535301282001955, # of labels: 17
# eps = 4750, min_samples = 5 - Silhouette Score: 0.5536219145980207, # of labels: 13
# eps = 4750, min_samples = 6 - Silhouette Score: 0.5565056312665444, # of labels: 12
# eps = 4750, min_samples = 7 - Silhouette Score: 0.5871115075233497, # of labels: 10
# eps = 5000, min_samples = 2 - Silhouette Score: -0.10022349627334474, # of labels: 94
# eps = 5000, min_samples = 3 - Silhouette Score: 0.5052263292536033, # of labels: 39
# eps = 5000, min_samples = 4 - Silhouette Score: 0.6221921793170738, # of labels: 17
# eps = 5000, min_samples = 5 - Silhouette Score: 0.6037954033150023, # of labels: 14
# eps = 5000, min_samples = 6 - Silhouette Score: 0.6016068297002991, # of labels: 11
# eps = 5000, min_samples = 7 - Silhouette Score: 0.5900209593743546, # of labels: 10
# eps = 5250, min_samples = 2 - Silhouette Score: -0.10245458524496251, # of labels: 95
# eps = 5250, min_samples = 3 - Silhouette Score: 0.4891672459859479, # of labels: 36
# eps = 5250, min_samples = 4 - Silhouette Score: 0.6385340747761705, # of labels: 17
# eps = 5250, min_samples = 5 - Silhouette Score: 0.6211016439290546, # of labels: 14
# eps = 5500, min_samples = 2 - Silhouette Score: -0.12196424620682397, # of labels: 99
# eps = 5500, min_samples = 3 - Silhouette Score: 0.4849071587771403, # of labels: 32
# eps = 5500, min_samples = 4 - Silhouette Score: 0.6181682309597557, # of labels: 17
# eps = 5500, min_samples = 5 - Silhouette Score: 0.6386643559591652, # of labels: 10
# eps = 5750, min_samples = 2 - Silhouette Score: -0.1272048075517282, # of labels: 96
# eps = 5750, min_samples = 3 - Silhouette Score: 0.4845624395485608, # of labels: 34
# eps = 5750, min_samples = 4 - Silhouette Score: 0.5882197128596384, # of labels: 16
# eps = 5750, min_samples = 5 - Silhouette Score: 0.630902062225463, # of labels: 11
# eps = 6000, min_samples = 2 - Silhouette Score: -0.14551469604830244, # of labels: 98
# eps = 6000, min_samples = 3 - Silhouette Score: 0.49202329965016955, # of labels: 29
# eps = 6000, min_samples = 4 - Silhouette Score: 0.5861077420448, # of labels: 19
# eps = 6000, min_samples = 5 - Silhouette Score: 0.6249819193305892, # of labels: 11
# eps = 6250, min_samples = 2 - Silhouette Score: -0.16663836142378574, # of labels: 94
# eps = 6250, min_samples = 3 - Silhouette Score: 0.05178938331996198, # of labels: 29
# eps = 6250, min_samples = 4 - Silhouette Score: 0.6699436039263277, # of labels: 18
# eps = 6250, min_samples = 5 - Silhouette Score: 0.6277883274421774, # of labels: 11
# eps = 6500, min_samples = 2 - Silhouette Score: -0.1744631883015595, # of labels: 93
# eps = 6500, min_samples = 3 - Silhouette Score: 0.04422347634188128, # of labels: 29
# eps = 6500, min_samples = 4 - Silhouette Score: 0.4847352688954933, # of labels: 16
# eps = 6500, min_samples = 5 - Silhouette Score: 0.6279202763084953, # of labels: 12
# eps = 6750, min_samples = 2 - Silhouette Score: -0.18189008279286326, # of labels: 90
# eps = 6750, min_samples = 3 - Silhouette Score: 0.036109965008226566, # of labels: 28
# eps = 6750, min_samples = 4 - Silhouette Score: 0.4806009863335474, # of labels: 16
# eps = 6750, min_samples = 5 - Silhouette Score: 0.6731304057823023, # of labels: 12
# eps = 7000, min_samples = 2 - Silhouette Score: -0.19547020943601517, # of labels: 95
# eps = 7000, min_samples = 3 - Silhouette Score: 0.010654651307239471, # of labels: 32
# eps = 7000, min_samples = 4 - Silhouette Score: 0.4764669551664228, # of labels: 17
# eps = 7000, min_samples = 5 - Silhouette Score: 0.4841769589185399, # of labels: 13
# eps = 7250, min_samples = 2 - Silhouette Score: -0.2093789338566423, # of labels: 91
# eps = 7250, min_samples = 3 - Silhouette Score: -0.008362860397007333, # of labels: 31
# eps = 7250, min_samples = 4 - Silhouette Score: 0.46354858662922943, # of labels: 16
# eps = 7250, min_samples = 5 - Silhouette Score: 0.4790084626924412, # of labels: 12
# eps = 7500, min_samples = 2 - Silhouette Score: -0.19870841131377381, # of labels: 86
# eps = 7500, min_samples = 3 - Silhouette Score: 0.43241556941858833, # of labels: 32
# eps = 7500, min_samples = 4 - Silhouette Score: 0.4587635989111887, # of labels: 17
# eps = 7500, min_samples = 5 - Silhouette Score: 0.47526846264218514, # of labels: 10
# eps = 7500, min_samples = 6 - Silhouette Score: 0.6899423111362524, # of labels: 10
# eps = 7750, min_samples = 2 - Silhouette Score: -0.21027854822054748, # of labels: 92
# eps = 7750, min_samples = 3 - Silhouette Score: 0.42082077547555685, # of labels: 32
# eps = 7750, min_samples = 4 - Silhouette Score: 0.44916241940364043, # of labels: 16
# eps = 7750, min_samples = 5 - Silhouette Score: 0.47417447929715484, # of labels: 10
# eps = 8000, min_samples = 2 - Silhouette Score: -0.21124122631724715, # of labels: 97
# eps = 8000, min_samples = 3 - Silhouette Score: 0.41933455936671693, # of labels: 38
# eps = 8000, min_samples = 4 - Silhouette Score: 0.4487244460097696, # of labels: 17
# eps = 8000, min_samples = 5 - Silhouette Score: 0.4608450659344587, # of labels: 11
# eps = 8250, min_samples = 2 - Silhouette Score: -0.20601753823167707, # of labels: 96
# eps = 8250, min_samples = 3 - Silhouette Score: 0.6236252450929043, # of labels: 37
# eps = 8250, min_samples = 4 - Silhouette Score: 0.460960715948873, # of labels: 17
# eps = 8250, min_samples = 5 - Silhouette Score: 0.4619786720210849, # of labels: 13
# eps = 8500, min_samples = 2 - Silhouette Score: 0.5644572782511378, # of labels: 96
# eps = 8500, min_samples = 3 - Silhouette Score: 0.6225399664604583, # of labels: 39
# eps = 8500, min_samples = 4 - Silhouette Score: 0.4574346209510163, # of labels: 15
# eps = 8500, min_samples = 5 - Silhouette Score: 0.45637369593675586, # of labels: 12
# eps = 8750, min_samples = 2 - Silhouette Score: 0.5643667165921529, # of labels: 92
# eps = 8750, min_samples = 3 - Silhouette Score: 0.6538072999109004, # of labels: 39
# eps = 8750, min_samples = 4 - Silhouette Score: 0.4566409161117697, # of labels: 20
# eps = 8750, min_samples = 5 - Silhouette Score: 0.4468928034325198, # of labels: 15
# eps = 9000, min_samples = 2 - Silhouette Score: 0.5556671578336005, # of labels: 89
# eps = 9000, min_samples = 3 - Silhouette Score: 0.6781597847518437, # of labels: 31
# eps = 9000, min_samples = 4 - Silhouette Score: 0.4563083987024144, # of labels: 17
# eps = 9000, min_samples = 5 - Silhouette Score: 0.45291521143755625, # of labels: 13
# eps = 9000, min_samples = 6 - Silhouette Score: 0.4534138509001947, # of labels: 11
# eps = 9250, min_samples = 2 - Silhouette Score: 0.5451385602276752, # of labels: 83
# eps = 9250, min_samples = 3 - Silhouette Score: 0.6712004291418108, # of labels: 27
# eps = 9250, min_samples = 4 - Silhouette Score: 0.44352111551990214, # of labels: 13
# eps = 9250, min_samples = 5 - Silhouette Score: 0.4446468174750435, # of labels: 10
# eps = 9250, min_samples = 6 - Silhouette Score: 0.4588764762060376, # of labels: 11
# eps = 9500, min_samples = 2 - Silhouette Score: 0.5449142396976786, # of labels: 77
# eps = 9500, min_samples = 3 - Silhouette Score: 0.6746486674521223, # of labels: 25
# eps = 9500, min_samples = 4 - Silhouette Score: 0.44795167514688, # of labels: 16
# eps = 9500, min_samples = 5 - Silhouette Score: 0.4298780619292158, # of labels: 10
# eps = 9750, min_samples = 2 - Silhouette Score: 0.5427278165812083, # of labels: 75
# eps = 9750, min_samples = 3 - Silhouette Score: 0.6730186344915867, # of labels: 23
# eps = 9750, min_samples = 4 - Silhouette Score: 0.44600704372279676, # of labels: 14
# eps = 10000, min_samples = 2 - Silhouette Score: 0.5419764067919883, # of labels: 78
# eps = 10000, min_samples = 3 - Silhouette Score: 0.6587342258157096, # of labels: 26
# eps = 10000, min_samples = 4 - Silhouette Score: 0.4466947063293794, # of labels: 15
# eps = 10000, min_samples = 5 - Silhouette Score: 0.4434702040461726, # of labels: 10
# eps = 10250, min_samples = 2 - Silhouette Score: 0.5408995413902963, # of labels: 77
# eps = 10250, min_samples = 3 - Silhouette Score: 0.6464305602092174, # of labels: 29
# eps = 10250, min_samples = 4 - Silhouette Score: 0.6681862511168946, # of labels: 15
# eps = 10250, min_samples = 5 - Silhouette Score: 0.44305825239624674, # of labels: 11
# eps = 10250, min_samples = 6 - Silhouette Score: 0.4528993309164628, # of labels: 11
# eps = 10500, min_samples = 2 - Silhouette Score: 0.5374645827784092, # of labels: 76
# eps = 10500, min_samples = 3 - Silhouette Score: 0.6637807305989801, # of labels: 26
# eps = 10500, min_samples = 4 - Silhouette Score: 0.6721282681446895, # of labels: 12
# eps = 10500, min_samples = 5 - Silhouette Score: 0.4372481117619613, # of labels: 13
# eps = 10500, min_samples = 6 - Silhouette Score: 0.45075295738096577, # of labels: 10
# eps = 10750, min_samples = 2 - Silhouette Score: 0.5358212026058199, # of labels: 73
# eps = 10750, min_samples = 3 - Silhouette Score: 0.6705586333097944, # of labels: 24
# eps = 10750, min_samples = 4 - Silhouette Score: 0.6718216865898415, # of labels: 12
# eps = 10750, min_samples = 5 - Silhouette Score: 0.6731958524983671, # of labels: 10
# eps = 11000, min_samples = 2 - Silhouette Score: 0.536561215535784, # of labels: 72
# eps = 11000, min_samples = 3 - Silhouette Score: 0.6678094792088629, # of labels: 24
# eps = 11000, min_samples = 4 - Silhouette Score: 0.6701266166238183, # of labels: 12
# eps = 11250, min_samples = 2 - Silhouette Score: 0.5365502154601167, # of labels: 74
# eps = 11250, min_samples = 3 - Silhouette Score: 0.6710364129908871, # of labels: 25
# eps = 11250, min_samples = 4 - Silhouette Score: 0.6696843299906499, # of labels: 12
# eps = 11500, min_samples = 2 - Silhouette Score: 0.5370120478983874, # of labels: 75
# eps = 11500, min_samples = 3 - Silhouette Score: 0.6716089791911554, # of labels: 26
# eps = 11500, min_samples = 4 - Silhouette Score: 0.670000410662901, # of labels: 14
# eps = 11750, min_samples = 2 - Silhouette Score: 0.5377397547328129, # of labels: 75
# eps = 11750, min_samples = 3 - Silhouette Score: 0.6714036346280647, # of labels: 26
# eps = 11750, min_samples = 4 - Silhouette Score: 0.6701526415790818, # of labels: 15
# eps = 11750, min_samples = 5 - Silhouette Score: 0.6777852154656617, # of labels: 10
# eps = 12000, min_samples = 2 - Silhouette Score: 0.5342200051177135, # of labels: 73
# eps = 12000, min_samples = 3 - Silhouette Score: 0.6699955363176927, # of labels: 22
# eps = 12000, min_samples = 4 - Silhouette Score: 0.6713384950754712, # of labels: 19
# eps = 12000, min_samples = 5 - Silhouette Score: 0.6745019899486043, # of labels: 11
# eps = 12250, min_samples = 2 - Silhouette Score: 0.5256445661943722, # of labels: 73
# eps = 12250, min_samples = 3 - Silhouette Score: 0.6636433095389198, # of labels: 22
# eps = 12250, min_samples = 4 - Silhouette Score: 0.6760610304980653, # of labels: 17
# eps = 12250, min_samples = 5 - Silhouette Score: 0.674494860410775, # of labels: 11
# eps = 12500, min_samples = 2 - Silhouette Score: 0.5215510449225974, # of labels: 73
# eps = 12500, min_samples = 3 - Silhouette Score: 0.6607975108452736, # of labels: 21
# eps = 12500, min_samples = 4 - Silhouette Score: 0.6720751063685825, # of labels: 14
# eps = 12750, min_samples = 2 - Silhouette Score: 0.5200808838588278, # of labels: 73
# eps = 12750, min_samples = 3 - Silhouette Score: 0.6549360352757183, # of labels: 22
# eps = 12750, min_samples = 4 - Silhouette Score: 0.6707591595538658, # of labels: 13
# eps = 12750, min_samples = 5 - Silhouette Score: 0.6716522041985825, # of labels: 10
# eps = 13000, min_samples = 2 - Silhouette Score: 0.5179014320642453, # of labels: 72
# eps = 13000, min_samples = 3 - Silhouette Score: 0.6583522122775995, # of labels: 20
# eps = 13000, min_samples = 4 - Silhouette Score: 0.6640831602541517, # of labels: 12
# eps = 13000, min_samples = 5 - Silhouette Score: 0.6713592753064332, # of labels: 10
# eps = 13250, min_samples = 2 - Silhouette Score: 0.5173473180047893, # of labels: 72
# eps = 13250, min_samples = 3 - Silhouette Score: 0.6580684880833326, # of labels: 22
# eps = 13250, min_samples = 4 - Silhouette Score: 0.6634833422241625, # of labels: 12
# eps = 13250, min_samples = 5 - Silhouette Score: 0.6686269957000708, # of labels: 10
# eps = 13500, min_samples = 2 - Silhouette Score: 0.5181800442134876, # of labels: 73
# eps = 13500, min_samples = 3 - Silhouette Score: 0.6581052664482262, # of labels: 24
# eps = 13500, min_samples = 4 - Silhouette Score: 0.6633062010196519, # of labels: 13
# eps = 13500, min_samples = 5 - Silhouette Score: 0.668519764973352, # of labels: 11
# eps = 13750, min_samples = 2 - Silhouette Score: 0.5290716972097582, # of labels: 70
# eps = 13750, min_samples = 3 - Silhouette Score: 0.6588085032206996, # of labels: 25
# eps = 13750, min_samples = 4 - Silhouette Score: 0.6618353695527533, # of labels: 13
# eps = 13750, min_samples = 5 - Silhouette Score: 0.6642342081421092, # of labels: 10
# eps = 14000, min_samples = 2 - Silhouette Score: 0.5282118298500849, # of labels: 68
# eps = 14000, min_samples = 3 - Silhouette Score: 0.661252378682183, # of labels: 24
# eps = 14000, min_samples = 4 - Silhouette Score: 0.6644904219049507, # of labels: 12
# eps = 14250, min_samples = 2 - Silhouette Score: 0.5274550432029443, # of labels: 65
# eps = 14250, min_samples = 3 - Silhouette Score: 0.6630311153030009, # of labels: 24
# eps = 14250, min_samples = 4 - Silhouette Score: 0.6629445646987033, # of labels: 14
# eps = 14500, min_samples = 2 - Silhouette Score: 0.5256622795177436, # of labels: 63
# eps = 14500, min_samples = 3 - Silhouette Score: 0.6620350181982583, # of labels: 23
# eps = 14500, min_samples = 4 - Silhouette Score: 0.6631493802934697, # of labels: 14
# eps = 14750, min_samples = 2 - Silhouette Score: 0.521489100593987, # of labels: 65
# eps = 14750, min_samples = 3 - Silhouette Score: 0.6589047763167655, # of labels: 22
# eps = 14750, min_samples = 4 - Silhouette Score: 0.6631691797530469, # of labels: 13
# eps = 14750, min_samples = 5 - Silhouette Score: 0.6630577893764894, # of labels: 10
# eps = 15000, min_samples = 2 - Silhouette Score: 0.6490484517599688, # of labels: 64
# eps = 15000, min_samples = 3 - Silhouette Score: 0.6579437340085377, # of labels: 22
# eps = 15000, min_samples = 4 - Silhouette Score: 0.6630719177749614, # of labels: 11
# eps = 15000, min_samples = 5 - Silhouette Score: 0.6622414998939838, # of labels: 11
# eps = 15250, min_samples = 2 - Silhouette Score: 0.6488049017215863, # of labels: 63
# eps = 15250, min_samples = 3 - Silhouette Score: 0.6579811397473952, # of labels: 23
# eps = 15250, min_samples = 4 - Silhouette Score: 0.6634209898246891, # of labels: 10
# eps = 15250, min_samples = 5 - Silhouette Score: 0.662746171478956, # of labels: 10
# eps = 15500, min_samples = 2 - Silhouette Score: 0.6473750530745863, # of labels: 60
# eps = 15500, min_samples = 3 - Silhouette Score: 0.6566406708125527, # of labels: 23
# eps = 15750, min_samples = 2 - Silhouette Score: 0.6471657891125213, # of labels: 61
# eps = 15750, min_samples = 3 - Silhouette Score: 0.656241071549985, # of labels: 22
# eps = 16000, min_samples = 2 - Silhouette Score: 0.6367922073645079, # of labels: 56
# eps = 16000, min_samples = 3 - Silhouette Score: 0.6496225414316986, # of labels: 19
# eps = 16000, min_samples = 4 - Silhouette Score: 0.6505913601828671, # of labels: 11
# eps = 16250, min_samples = 2 - Silhouette Score: 0.6362594307632519, # of labels: 53
# eps = 16250, min_samples = 3 - Silhouette Score: 0.6496423059472025, # of labels: 21
# eps = 16250, min_samples = 4 - Silhouette Score: 0.6501494275042222, # of labels: 11
# eps = 16500, min_samples = 2 - Silhouette Score: 0.6808060146170659, # of labels: 48
# eps = 16500, min_samples = 3 - Silhouette Score: 0.7056214450637882, # of labels: 19
# eps = 16500, min_samples = 4 - Silhouette Score: 0.7068370627101767, # of labels: 11
# eps = 16750, min_samples = 2 - Silhouette Score: 0.6809172078495156, # of labels: 52
# eps = 16750, min_samples = 3 - Silhouette Score: 0.7056214450637882, # of labels: 19
# eps = 16750, min_samples = 4 - Silhouette Score: 0.70587290302572, # of labels: 10
# Best Params: {'eps': 16500, 'min_samples': 4} with Silhouette Score: 0.7068370627101767

# %%
X, Y = np.meshgrid(min_samples, epsilons)
plt.figure(figsize=(8, 6))
plt.pcolormesh(X, Y, sil_scores, shading='auto')
plt.colorbar(label='Silhouette score')
plt.xlabel('min_samples')
plt.ylabel('epsilon size')
plt.title('DBSCAN search')
plt.savefig('Images/Anime Recommendation/DBSCAN.png')

# %%
# Get positions of sil_scores greater than 0.7
indices = np.argwhere(sil_scores > 0.7)

# Get number of labels
num_clusters = [num_of_labels[(ii[0], ii[1])] for ii in indices]
sil_scores_dbscan = [sil_scores[(ii[0], ii[1])] for ii in indices]

plt.scatter(num_clusters, sil_scores_dbscan)
plt.xlabel('# of cluster')
plt.ylabel('Silhouette score')
plt.title('DBSCAN')
plt.savefig('Images/Anime Recommendation/DBSCAN_above_07.png')
